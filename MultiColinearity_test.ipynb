# %%
import pandas as pd
import numpy as np
import  seaborn as sns
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('storedata.csv')

# %%
df
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina     -2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vit�ria      7
# 132                          Sandy      UK     96858       Mat�as      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score         Location  \
# 0          18526     121      Yes                 10      Retail Park
# 1          18569     121      Yes                 11  Shopping Centre
# 2          12288     105       No                 12      Retail Park
# 3          17092     117       No                 14      High Street
# 4          11307     103       No                 18      Retail Park
# ..           ...     ...      ...                ...              ...
# 131        14120     110      Yes                 13      Retail Park
# 132        11205     103       No                 15  Shopping Centre
# 133        16190     115       No                 19  Shopping Centre
# 134        15516     113       No                 17      High Street
# 135        14468     111      Yes                 18      High Street
#
#      40min population  30 min population  20 min population  \
# 0             1288374            1138224            1006986
# 1             1086225            1015321            1012182
# 2             1595638            1281661            1104490
# 3             1179395            1022959            1009496
# 4             1398558            1085170            1003137
# ..                ...                ...                ...
# 131           1665074            1240813            1141898
# 132           1657769            1424404            1378708
# 133           1407456            1359511            1200486
# 134           1451087            1245725            1127276
# 135           1706344            1307752            1159859
#
#      10 min population  Store age  Clearance space  Competition number  \
# 0              1002340          3              238                  16
# 1              1008436          4              384                  15
# 2              1011395         11              219                  13
# 3              1002169          5              261                  15
# 4              1002513          7              200                  19
# ..                 ...        ...              ...                 ...
# 131            1041041          6              202                  18
# 132            1160929          5              203                  13
# 133            1063718          7              341                  18
# 134            1045154         11              261                  14
# 135            1020940          8              276                  18
#
#      Competition score Performance
# 0                   16        Good
# 1                   19        Good
# 2                   18         Bad
# 3                   12         Bad
# 4                   13         Bad
# ..                 ...         ...
# 131                 14         Bad
# 132                 18         Bad
# 133                 18         Bad
# 134                 10         Bad
# 135                 13        Good
#
# [136 rows x 19 columns]

# %%
df.shape
# Out:
# (136, 19)

# %%
df.dtypes
# Out:
# Town                  object
# Country               object
# Store ID               int64
# Manager name          object
# Staff                  int64
# Floor Space            int64
# Window                 int64
# Car park              object
# Demographic score      int64
# Location              object
# 40min population       int64
# 30 min population      int64
# 20 min population      int64
# 10 min population      int64
# Store age              int64
# Clearance space        int64
# Competition number     int64
# Competition score      int64
# Performance           object
# dtype: object

# %%
df.isna().sum()
# Out:
# Town                  0
# Country               0
# Store ID              0
# Manager name          0
# Staff                 0
# Floor Space           0
# Window                0
# Car park              0
# Demographic score     0
# Location              0
# 40min population      0
# 30 min population     0
# 20 min population     0
# 10 min population     0
# Store age             0
# Clearance space       0
# Competition number    0
# Competition score     0
# Performance           0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Town                  0
# Country               0
# Store ID              0
# Manager name          0
# Staff                 0
# Floor Space           0
# Window                0
# Car park              0
# Demographic score     0
# Location              0
# 40min population      0
# 30 min population     0
# 20 min population     0
# 10 min population     0
# Store age             0
# Clearance space       0
# Competition number    0
# Competition score     0
# Performance           0
# dtype: int64

# %%
df['Manager name'].unique()
# Out:
# array(['Roger', 'Ella', 'Valentina', 'Antonia', 'Gabriel', 'Sarah',
#        'James', 'Ashley', 'Guilherme', 'Grace', 'Franco', 'Olivia',
#        'Emily', 'Matheus', 'Megane', 'Samuel', 'Emma', 'Agustina',
#        'Justin', 'Sebasti�n', 'Isabella', 'Laurence', 'J�lia', 'Luc�a',
#        'Nicol�s', 'Sof�a', 'Luiz', 'Abigail', 'Fernanda', 'Mart�n',
#        'Nathan', 'Francisca', 'Vin�cius', 'Madison', 'Hannah', 'Antony',
#        'Tom�s', 'Samantha', 'Ryan', 'Logan', 'Sydney', 'Jeremy',
#        'Larissa', 'Ava', 'Jacob', 'Yasmin', 'Vicente', 'Ethan', 'Micaela',
#        'Matthew', 'Jo�o', 'Taylor', 'Xavier', 'Beatriz', 'Olivier',
#        'Christopher', 'Sophia', 'Dylan', 'Jessica', 'Ana', 'Connor',
#        'Julie', 'Liam', 'Jo', 'Victoria', 'Daniel', 'Camila', 'Lucas',
#        'Diego', 'Megan', 'Martina', 'Noemie', 'Rosalie', 'Andrew',
#        'Catalina', 'Alexis', 'Giovanna', 'Jos�', 'Felix', 'Audrey',
#        'Nicholas', 'Benjam�n', 'Crist�bal', 'Noah', 'Joshua', 'Maria',
#        'Kate', 'Michael', 'Thiago', 'Alexander', 'Coralie', 'Lautaro',
#        'Camille', 'Antoine', 'Mariana', 'William', 'Amy', 'Santiago',
#        'Javiera', 'Milagros', 'Jade', 'Agust�n', 'Anthony', 'Tyler',
#        'Juan', 'Thomas', 'Paige', 'Mar�a', 'Constanza', 'Joaqu�n',
#        'Pedro', 'Julieta', 'Let�cia', 'Vit�ria', 'Mat�as', 'Gustavo',
#        'Rafael', 'Lea'], dtype=object)

# %%
def func(x):
    # lister = []
    gene = x.to_list()
    for i in range(len(gene)):
        if gene[i] == 'Sebasti�n':
            gene[i] = 'Sebatian'        
    
        elif gene[i] == 'J�lia':
            gene[i] = 'Julia'
            
        elif gene[i] == 'Nicol�s':
            gene[i] = 'Nicolas'
            
        elif gene[i] == 'Sof�a':
            gene[i] = 'Sofia'
            
        elif gene[i] == 'Luc�a':
            gene[i] = 'Lucia'
            
        elif gene[i] == 'Mart�n':
            gene[i] = 'Martin'
           
        elif gene[i] == 'Mart�n':
            gene[i] = 'Martin'
               
        elif gene[i] == 'Vin�cius':
            gene[i] = 'Vinicius'
               
        elif gene[i] == 'Tom�s':
            gene[i] = 'Tomas'
            
        elif gene[i] == 'Jo�o':
            gene[i] = 'Jojo'
            
        elif gene[i] == 'Jos�':
            gene[i] = 'Jose'
                   
        elif gene[i] == 'Benjam�n':
            gene[i] = 'Benjamin'
                   
        elif gene[i] == 'Crist�bal':
            gene[i] = 'Cristabal'
                   
        elif gene[i] == 'Agust�n':
            gene[i] = 'Agustin'
                   
        elif gene[i] == 'Mar�a':
            gene[i] = 'Maria'
                       
        elif gene[i] == 'Joaqu�n':
            gene[i] = 'Joaquan'
                       
        elif gene[i] == 'Let�cia':
            gene[i] = 'Leticia'
                       
        elif gene[i] == 'Vit�ria':
            gene[i] = 'Vitoria'  
                            
        elif gene[i] == 'Mat�as':
            gene[i] = 'Matias'   
            
    return gene

df['Manager name'] = func(df['Manager name'])

# %%
df['Manager name'].unique()
# Out:
# array(['Roger', 'Ella', 'Valentina', 'Antonia', 'Gabriel', 'Sarah',
#        'James', 'Ashley', 'Guilherme', 'Grace', 'Franco', 'Olivia',
#        'Emily', 'Matheus', 'Megane', 'Samuel', 'Emma', 'Agustina',
#        'Justin', 'Sebatian', 'Isabella', 'Laurence', 'Julia', 'Lucia',
#        'Nicolas', 'Sofia', 'Luiz', 'Abigail', 'Fernanda', 'Martin',
#        'Nathan', 'Francisca', 'Vinicius', 'Madison', 'Hannah', 'Antony',
#        'Tomas', 'Samantha', 'Ryan', 'Logan', 'Sydney', 'Jeremy',
#        'Larissa', 'Ava', 'Jacob', 'Yasmin', 'Vicente', 'Ethan', 'Micaela',
#        'Matthew', 'Jojo', 'Taylor', 'Xavier', 'Beatriz', 'Olivier',
#        'Christopher', 'Sophia', 'Dylan', 'Jessica', 'Ana', 'Connor',
#        'Julie', 'Liam', 'Jo', 'Victoria', 'Daniel', 'Camila', 'Lucas',
#        'Diego', 'Megan', 'Martina', 'Noemie', 'Rosalie', 'Andrew',
#        'Catalina', 'Alexis', 'Giovanna', 'Jose', 'Felix', 'Audrey',
#        'Nicholas', 'Benjamin', 'Cristabal', 'Noah', 'Joshua', 'Maria',
#        'Kate', 'Michael', 'Thiago', 'Alexander', 'Coralie', 'Lautaro',
#        'Camille', 'Antoine', 'Mariana', 'William', 'Amy', 'Santiago',
#        'Javiera', 'Milagros', 'Jade', 'Agustin', 'Anthony', 'Tyler',
#        'Juan', 'Thomas', 'Paige', 'Constanza', 'Joaquan', 'Pedro',
#        'Julieta', 'Leticia', 'Vitoria', 'Matias', 'Gustavo', 'Rafael',
#        'Lea'], dtype=object)

# %%
df.columns
# Out:
# Index(['Town', 'Country', 'Store ID', 'Manager name', 'Staff', 'Floor Space',
#        'Window', 'Car park', 'Demographic score', 'Location',
#        '40min population', '30 min population', '20 min population',
#        '10 min population', 'Store age', 'Clearance space',
#        'Competition number', 'Competition score', 'Performance'],
#       dtype='object')

# %%
df['Car park'].unique()
# Out:
# array(['Yes', 'No', 'Y', 'N'], dtype=object)

# %%
def car(x):
    cruise = x.to_list()
    for i in range(len(cruise)):
        if cruise[i] == 'N':
            cruise[i] = 'No'
        
        elif cruise[i] == 'Y':
            cruise[i] = 'Yes'
            
    return cruise

df['Car park'] = car(df['Car park'])

# %%
df['Car park'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.dtypes
# Out:
# Town                  object
# Country               object
# Store ID               int64
# Manager name          object
# Staff                  int64
# Floor Space            int64
# Window                 int64
# Car park              object
# Demographic score      int64
# Location              object
# 40min population       int64
# 30 min population      int64
# 20 min population      int64
# 10 min population      int64
# Store age              int64
# Clearance space        int64
# Competition number     int64
# Competition score      int64
# Performance           object
# dtype: object

# %%
df['Town'].value_counts()
# Out:
#  Swinton (Greater Manchester)    1
#  Shoreham-by-Sea                 1
#  South Cave                      1
#  Settle                          1
#  Sleaford                        1
#                                 ..
#  Stainforth                      1
#  Swindon                         1
#  Stanford-le-Hope                1
#  Shefford                        1
#  Stapleford                      1
# Name: Town, Length: 136, dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['UK', 'France'], dtype=object)

# %%
df['Location'].unique()
# Out:
# array(['Retail Park', 'Shopping Centre', 'High Street', 'Village'],
#       dtype=object)

# %%
df['Performance'].unique()
# Out:
# array(['Good', 'Bad'], dtype=object)

# %%
df.corr()
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_8916\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     Store ID     Staff  Floor Space    Window  \
# Store ID            1.000000  0.069173     0.014658  0.014756
# Staff               0.069173  1.000000     0.076039  0.077630
# Floor Space         0.014658  0.076039     1.000000  0.999208
# Window              0.014756  0.077630     0.999208  1.000000
# Demographic score   0.174201 -0.057831     0.038187  0.038633
# 40min population    0.070286 -0.098366     0.051918  0.053228
# 30 min population   0.015162 -0.024631    -0.032199 -0.028688
# 20 min population   0.058195 -0.056310    -0.046161 -0.042441
# 10 min population   0.072882 -0.006601    -0.096698 -0.091651
# Store age           0.008830 -0.172655    -0.049285 -0.048992
# Clearance space     0.072401  0.110591     0.627324  0.628509
# Competition number  0.156863  0.034571     0.073559  0.074034
# Competition score  -0.077005  0.123579     0.091447  0.104551
#
#                     Demographic score  40min population  30 min population  \
# Store ID                     0.174201          0.070286           0.015162
# Staff                       -0.057831         -0.098366          -0.024631
# Floor Space                  0.038187          0.051918          -0.032199
# Window                       0.038633          0.053228          -0.028688
# Demographic score            1.000000          0.036694          -0.007616
# 40min population             0.036694          1.000000           0.624732
# 30 min population           -0.007616          0.624732           1.000000
# 20 min population            0.053498          0.516682           0.766158
# 10 min population            0.099587          0.432857           0.667031
# Store age                   -0.014967         -0.191329          -0.098829
# Clearance space              0.041849         -0.018234          -0.093048
# Competition number          -0.100716         -0.004326          -0.054191
# Competition score           -0.072325          0.040554           0.046811
#
#                     20 min population  10 min population  Store age  \
# Store ID                     0.058195           0.072882   0.008830
# Staff                       -0.056310          -0.006601  -0.172655
# Floor Space                 -0.046161          -0.096698  -0.049285
# Window                      -0.042441          -0.091651  -0.048992
# Demographic score            0.053498           0.099587  -0.014967
# 40min population             0.516682           0.432857  -0.191329
# 30 min population            0.766158           0.667031  -0.098829
# 20 min population            1.000000           0.807882  -0.046910
# 10 min population            0.807882           1.000000  -0.103815
# Store age                   -0.046910          -0.103815   1.000000
# Clearance space             -0.085887          -0.053129  -0.037935
# Competition number          -0.081947          -0.039108  -0.063024
# Competition score            0.008492           0.068781  -0.109725
#
#                     Clearance space  Competition number  Competition score
# Store ID                   0.072401            0.156863          -0.077005
# Staff                      0.110591            0.034571           0.123579
# Floor Space                0.627324            0.073559           0.091447
# Window                     0.628509            0.074034           0.104551
# Demographic score          0.041849           -0.100716          -0.072325
# 40min population          -0.018234           -0.004326           0.040554
# 30 min population         -0.093048           -0.054191           0.046811
# 20 min population         -0.085887           -0.081947           0.008492
# 10 min population         -0.053129           -0.039108           0.068781
# Store age                 -0.037935           -0.063024          -0.109725
# Clearance space            1.000000            0.047191           0.156431
# Competition number         0.047191            1.000000          -0.011215
# Competition score          0.156431           -0.011215           1.000000

# %%
df_location = pd.get_dummies(df['Location'], prefix ='location')
df= pd.concat([df, df_location], axis = 1)
del df['Location']

# %%
df
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina     -2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vitoria      7
# 132                          Sandy      UK     96858       Matias      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score  40min population  ...  \
# 0          18526     121      Yes                 10           1288374  ...
# 1          18569     121      Yes                 11           1086225  ...
# 2          12288     105       No                 12           1595638  ...
# 3          17092     117       No                 14           1179395  ...
# 4          11307     103       No                 18           1398558  ...
# ..           ...     ...      ...                ...               ...  ...
# 131        14120     110      Yes                 13           1665074  ...
# 132        11205     103       No                 15           1657769  ...
# 133        16190     115       No                 19           1407456  ...
# 134        15516     113       No                 17           1451087  ...
# 135        14468     111      Yes                 18           1706344  ...
#
#      10 min population  Store age  Clearance space  Competition number  \
# 0              1002340          3              238                  16
# 1              1008436          4              384                  15
# 2              1011395         11              219                  13
# 3              1002169          5              261                  15
# 4              1002513          7              200                  19
# ..                 ...        ...              ...                 ...
# 131            1041041          6              202                  18
# 132            1160929          5              203                  13
# 133            1063718          7              341                  18
# 134            1045154         11              261                  14
# 135            1020940          8              276                  18
#
#      Competition score  Performance  location_High Street  \
# 0                   16         Good                     0
# 1                   19         Good                     0
# 2                   18          Bad                     0
# 3                   12          Bad                     1
# 4                   13          Bad                     0
# ..                 ...          ...                   ...
# 131                 14          Bad                     0
# 132                 18          Bad                     0
# 133                 18          Bad                     0
# 134                 10          Bad                     1
# 135                 13         Good                     1
#
#     location_Retail Park  location_Shopping Centre  location_Village
# 0                      1                         0                 0
# 1                      0                         1                 0
# 2                      1                         0                 0
# 3                      0                         0                 0
# 4                      1                         0                 0
# ..                   ...                       ...               ...
# 131                    1                         0                 0
# 132                    0                         1                 0
# 133                    0                         1                 0
# 134                    0                         0                 0
# 135                    0                         0                 0
#
# [136 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Town', 'Country', 'Store ID', 'Manager name', 'Staff', 'Floor Space',
#        'Window', 'Car park', 'Demographic score', '40min population',
#        '30 min population', '20 min population', '10 min population',
#        'Store age', 'Clearance space', 'Competition number',
#        'Competition score', 'Performance', 'location_High Street',
#        'location_Retail Park', 'location_Shopping Centre', 'location_Village'],
#       dtype='object')

# %%
df[['Town', 'Store ID', 'Manager name', 'Staff', 'Floor Space', 'Window',
       'Demographic score', '40min population', '30 min population',
       '20 min population', '10 min population', 'Store age',
       'Clearance space', 'Competition number', 'Competition score', 'Performance', 'Car park', 'Country']] = df[['Town', 'Store ID', 'Manager name', 'Staff', 'Floor Space', 'Window',
       'Demographic score', '40min population', '30 min population',
       '20 min population', '10 min population', 'Store age',
       'Clearance space', 'Competition number', 'Competition score', 'Performance', 'Car park', 'Country']].apply(LabelEncoder().fit_transform)

# %%
df
# Out:
#      Town  Country  Store ID  Manager name  Staff  Floor Space  Window  \
# 0     132        1         0            93      5          113      21
# 1      95        1         1            28      4          115      21
# 2      52        1         2           109      0           30       5
# 3     115        1         3            10      3           96      17
# 4      32        1         4            36      3           12       3
# ..    ...      ...       ...           ...    ...          ...     ...
# 131    61        1       131           113      3           57      10
# 132    12        1       132            76      2           11       3
# 133    29        1       133            40      3           85      15
# 134     2        1       134            92      2           77      13
# 135    98        1       135            63      5           64      11
#
#      Car park  Demographic score  40min population  ...  10 min population  \
# 0           1                  0                39  ...                 26
# 1           1                  1                12  ...                 40
# 2           0                  2                85  ...                 47
# 3           0                  4                27  ...                 24
# 4           0                  8                53  ...                 27
# ..        ...                ...               ...  ...                ...
# 131         1                  3                96  ...                 75
# 132         0                  5                94  ...                118
# 133         0                  9                54  ...                 90
# 134         0                  7                59  ...                 79
# 135         1                  8               103  ...                 59
#
#      Store age  Clearance space  Competition number  Competition score  \
# 0            1               27                   6                  6
# 1            2               86                   5                  9
# 2            9               12                   3                  8
# 3            3               41                   5                  2
# 4            5                0                   9                  3
# ..         ...              ...                 ...                ...
# 131          4                1                   8                  4
# 132          3                2                   3                  8
# 133          5               76                   8                  8
# 134          9               41                   4                  0
# 135          6               52                   8                  3
#
#      Performance  location_High Street  location_Retail Park  \
# 0              1                     0                     1
# 1              1                     0                     0
# 2              0                     0                     1
# 3              0                     1                     0
# 4              0                     0                     1
# ..           ...                   ...                   ...
# 131            0                     0                     1
# 132            0                     0                     0
# 133            0                     0                     0
# 134            0                     1                     0
# 135            1                     1                     0
#
#      location_Shopping Centre  location_Village
# 0                           0                 0
# 1                           1                 0
# 2                           0                 0
# 3                           0                 0
# 4                           0                 0
# ..                        ...               ...
# 131                         0                 0
# 132                         1                 0
# 133                         1                 0
# 134                         0                 0
# 135                         0                 0
#
# [136 rows x 22 columns]

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >

# %%
def corre(df, thre):
    corr_cols = set()
    corr = df.corr()
    for i in range(len(corr.columns)):
        for j in range(i):
            if abs(corr.iloc[i,j]) > thre:
                cols = corr.columns[i]
                corr_cols.add(cols)
                
    return corr_cols

corre(df, 0.6)
# Out:
# {'10 min population', '20 min population', 'Clearance space', 'Window'}

# %%
df = df.drop([ 'Window','10 min population', '20 min population', 'Clearance space'], axis =1)

# %%
X = df.drop(['Performance'], axis = 1)
y = df['Performance']

# %%
X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=0.5, random_state=1)

# %%
ln = sm.OLS(y_train,X_train).fit()
print(ln.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Performance   R-squared:                       0.517
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     4.057
# Date:                Sun, 30 Apr 2023   Prob (F-statistic):           9.89e-05
# Time:                        15:01:53   Log-Likelihood:                -24.472
# No. Observations:                  68   AIC:                             78.94
# Df Residuals:                      53   BIC:                             112.2
# Df Model:                          14
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Town                         0.0015      0.001      1.130      0.264      -0.001       0.004
# Country                     -0.2831      0.214     -1.322      0.192      -0.712       0.146
# Store ID                    -0.0011      0.001     -0.757      0.453      -0.004       0.002
# Manager name                 0.0013      0.002      0.769      0.446      -0.002       0.005
# Staff                        0.1099      0.037      2.946      0.005       0.035       0.185
# Floor Space                  0.0029      0.001      2.121      0.039       0.000       0.006
# Car park                     0.0856      0.117      0.729      0.469      -0.150       0.321
# Demographic score           -0.0213      0.018     -1.186      0.241      -0.057       0.015
# 40min population            -0.0010      0.002     -0.517      0.607      -0.005       0.003
# 30 min population            0.0006      0.002      0.307      0.760      -0.003       0.004
# Store age                    0.0007      0.019      0.037      0.970      -0.036       0.038
# Competition number           0.0195      0.020      0.999      0.323      -0.020       0.059
# Competition score            0.0506      0.018      2.879      0.006       0.015       0.086
# location_High Street        -0.2626      0.099     -2.644      0.011      -0.462      -0.063
# location_Retail Park        -0.1133      0.102     -1.111      0.272      -0.318       0.091
# location_Shopping Centre     0.0928      0.107      0.867      0.390      -0.122       0.307
# location_Village                  0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        5.408   Durbin-Watson:                   1.814
# Prob(Omnibus):                  0.067   Jarque-Bera (JB):                2.322
# Skew:                           0.054   Prob(JB):                        0.313
# Kurtosis:                       2.101   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\users\kodaks\appdata\local\programs\python\python39\lib\site-packages\statsmodels\regression\linear_model.py:1934: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])

# %%
regr = LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = regr.predict(X_test)

# %%
regr.score(X_test,y_test)
# Out:
# 0.4442166680795663

# %%
regr.score(X_train, y_train)
# Out:
# 0.5172949485053253
